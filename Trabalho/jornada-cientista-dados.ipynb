# %% [markdown]
# # Jornada do cientista de dados no DNIT

# %% [markdown]
# ## Fontes de dados:
#
# https://servicos.dnit.gov.br/dadosabertos/dataset/?tags=infraestrutura-rodoviaria
#
# https://servicos.dnit.gov.br/dadospnct
#
# https://dados.transportes.gov.br/dataset/renaest
#
# https://Dataverse.fgv.br
#
# https://dataverse.org/
#
# https://www.ibge.gov.br/estatisticas/downloads-estatisticas.html
#
# https://Data.rio

# %% [markdown]
# ## Carga de exemplo: Contagem de Tráfego
#
# https://servicos.dnit.gov.br/dadosabertos/dataset/contagem-de-trafego
#
# O dicionário de dados do arquivo "contagem-de-trafego-dicionario.pdf", referente à Contagem de Tráfego – SNV 202001A, foi extraído e convertido para uma tabela Markdown equivalente.[1]
#
# ## Tabela de Campos
#
# | Campo          | Tipo          | Descrição [1] |
# |----------------|---------------|---------------------|
# | ID             | Numérico     | id - Chave Primária Base Georreferenciada (base com quebras no SNV) |
# | id_trecho_     | Numérico     | Campos da Base Georreferenciada original do SNV 202001A |
# | vl_br          | Numérico     | Campos da Base Georreferenciada original do SNV 202001A |
# | sg_uf          | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | nm_tipo_tr     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | sg_tipo_tr     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | desc_coinc     | Numérico     | Campos da Base Georreferenciada original do SNV 202001A |
# | vl_codigo      | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_local_i     | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_local_f     | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | vl_km_inic     | Numérico     | Campos da Base Georreferenciada original do SNV 202001A |
# | vl_km_fina     | Numérico     | Campos da Base Georreferenciada original do SNV 202001A |
# | vl_extensa     | Numérico     | Campos da Base Georreferenciada original do SNV 202001A |
# | vl_km_i_estim  | Numérico     | Estimativa de km inicial do trecho (decorrente das quebras realizadas no SNV) |
# | vl_km_f_estim  | Numérico     | Estimativa de km final do trecho (decorrente das quebras realizadas no SNV) |
# | vl_ext_estim   | Numérico     | Estimativa de extensão do trecho (decorrente das quebras realizadas no SNV) |
# | ds_sup_fed     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_obra        | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_coinc       | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_tipo_ad     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_ato_leg     | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | est_coinc      | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | sup_est_co     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_jurisdi     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_superfi     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | ds_legenda     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | sg_legenda     | Texto        | Campos da Base Georreferenciada original do SNV 202001A |
# | leg_multim     | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | versao_snv     | Alfanumérico | Campos da Base Georreferenciada original do SNV 202001A |
# | id_versao      | Numérico     | Campos da Base Georreferenciada original do SNV 202001A |
# | classificação  | Texto        | Classificação de Links Referenciais e Não Simuláveis (o uso do VMDa deve ser restrito ou complementado por análises pontuais caso a caso): "Referencial" - Identifica links da rede utilizados como Count Location na rede; "Não Simulável" - Identifica links da rede que estão próximos, ou sofrem influência direta, de grandes áreas urbanas e/ou regiões metropolitanas; "Não Pavimentada" - Identifica links da rede não pavimentados; "Travessia - Não Simulável" - Identifica links da rede que são travessias; "Planejada" - Identifica links planejados do SNV |
# | GEH            | Texto        | Classificação de Links Referenciais conforme GEH obtido |
# | A_C ... J_C    | Numérico     | Volume estimado (VMDa) para a Categoria do PNCT - Sentido Crescente (aplica-se a cada letra) |
# | A_D ... J_D    | Numérico     | Volume estimado (VMDa) para a Categoria do PNCT - Sentido Decrescente (aplica-se a cada letra) |
# | VMDa_C         | Numérico     | Volume estimado (VMDa) Total - Sentido Crescente |
# | VMDa_D         | Numérico     | Volume estimado (VMDa) Total - Sentido Decrescente |
# | NS_C           | Texto        | Nível de serviço indicativo - Sentido Crescente |
# | NS_D           | Texto        | Nível de serviço indicativo - Sentido Decrescente |

# %% [markdown]
# - Download de 2020
# - conferir colunas e tipos de dados
# - carregar num data frame R
# - rodar estatisticas descritivas - scatter plot
